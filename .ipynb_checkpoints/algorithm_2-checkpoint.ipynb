# %% [markdown]
# # Algorithm 2

# %% [markdown]
# ### PART 1 -
# #### Execute KMeans.
# Try to find automatticaly the 'elbow' - the best K results ( withour relating to the daily hours or to the number of resources).
#
# ### PART 2 -
# #### Order The Clusters.
#  * 2a- Index all datapoints (jobs) in a cluster with the same index, when indexing is according to the distance between the clusters.
#  * 2b- Execute Shortest Path algorithm at each cluster, connect the cluster by the closest datapoints (jobs). (Index each datapoint with different index)

# %%
import sys
import numpy as np # used for scientific computing\n",
import pandas as pd # used for data analysis and manipulation\n",
import matplotlib.pyplot as plt # used for visualization and plotting\n",
import matplotlib.cm as cm
import math
from sklearn.cluster import KMeans 
import heapq

# %%
name_of_file = 'forth_dataset'

# %%
# read the data
df = pd.read_excel(f'Data/{name_of_file}.xlsx')

# %%
# verify the data
df
# Out:
#                          _                  Id AppointmentNumber   Latitude  \
# 0     [ServiceAppointment]  08p4L000000lKo4QAE           SA-5319  19.460891
# 1     [ServiceAppointment]  08p4L000000lKo5QAE           SA-5320  19.368634
# 2     [ServiceAppointment]  08p4L000000lKoCQAU           SA-5327  19.493341
# 3     [ServiceAppointment]  08p4L000000lKoDQAU           SA-5328  19.462779
# 4     [ServiceAppointment]  08p4L000000lKo9QAE           SA-5324  19.487029
# ...                    ...                 ...               ...        ...
# 1595  [ServiceAppointment]  08p4L000000lKqwQAE           SA-5497  19.404777
# 1596  [ServiceAppointment]  08p4L000000lKqsQAE           SA-5493  19.453365
# 1597  [ServiceAppointment]  08p4L000000lKqtQAE           SA-5494  19.452480
# 1598  [ServiceAppointment]  08p4L000000lKqxQAE           SA-5498  19.457710
# 1599  [ServiceAppointment]  08p4L000000lKquQAE           SA-5495  28.391000
#
#        Longitude  IDC_Index__c
# 0     -99.139634           NaN
# 1     -99.145334           NaN
# 2     -99.190447           NaN
# 3     -99.135322           NaN
# 4     -99.198889           NaN
# ...          ...           ...
# 1595  -99.169003           NaN
# 1596  -99.130240           NaN
# 1597  -99.145865           NaN
# 1598  -99.143010           NaN
# 1599 -106.861350           NaN
#
# [1600 rows x 6 columns]

# %%
def plot(c): 
    plt.scatter(df['Latitude'], df['Longitude'], color=c)

# %%
# map of the jobs
plot('blue')

# %%
# extract the relvent columns
dataset = np.array(df[['Latitude', 'Longitude']])

# %%
# verify the exctraction
dataset
# Out:
# array([[  19.460891,  -99.139634],
#        [  19.368634,  -99.145334],
#        [  19.493341,  -99.190447],
#        ...,
#        [  19.45248 ,  -99.145865],
#        [  19.45771 ,  -99.14301 ],
#        [  28.391   , -106.86135 ]])

# %% [markdown]
# # PART 1 - KMEANS

# %%
# K to check for the KMeans
Ks = [k for k in range(4, 150)]

# %%
# execute KMeans for each K in Ks
inertia_lst = []
for k in Ks:
    kmeans = KMeans(n_clusters=k, random_state=0)
    # fit the data
    _ = kmeans.fit_predict(dataset)
    # save inertia
    inertia_lst.append(kmeans.inertia_)

# %%
# plot inertia as function of number of clusers (k)
plt.plot(Ks, inertia_lst, marker=11)

# %% [markdown]
# finding the elbow is the method to find the best K.
# The solution is not optimal which means it is not return the best result any time.
# In contrast, the result will be always close to the truth and the small error may not affect on our results drastically.

# %%
# finding the elbow
length = len(inertia_lst) - 1

# delta_1: index=0 -> #cluster=2 -> best_k_idx=1
delta_1 = [inertia_lst[i] - inertia_lst[i+1] for i in range(length)]

# delta_2: index 0 -> #cluster=3 -> best_k_idx=2
delta_2 = [delta_1[i] - delta_1[i+1] for i in range(length - 1)]

strength = [(i, delta_2[i+1] - delta_1[i+2]) for i in range(length - 2) if delta_1[i+1] >= 0 and delta_2[i+1] >= 0]

best_k_idx = max(strength,key=lambda t: t[1])[0] + 2
best_k = Ks[best_k_idx]

# %%
# get the best KMeans , n_clusters=best_k
best_kmeans = KMeans(n_clusters=best_k, random_state=0)

# %%
# seperate the instances to clusters

# get labels 
labels = best_kmeans.fit_predict(dataset)

# init dictionary
dict_of_clusters = {cluster: [] for cluster in range(best_k)}

for idx, instance in enumerate(dataset):
    dict_of_clusters[labels[idx]].append(instance)

# %%
# print cluster sizes
for cluster, instances in dict_of_clusters.items():
    print(f'------Cluster {cluster}: {len(instances)} jobs --------')
    print()
# Out:
# ------Cluster 0: 21 jobs --------
#
# ------Cluster 1: 5 jobs --------
#
# ------Cluster 2: 6 jobs --------
#
# ------Cluster 3: 123 jobs --------
#
# ------Cluster 4: 18 jobs --------
#
# ------Cluster 5: 30 jobs --------
#
# ------Cluster 6: 48 jobs --------
#
# ------Cluster 7: 42 jobs --------
#
# ------Cluster 8: 17 jobs --------
#
# ------Cluster 9: 64 jobs --------
#
# ------Cluster 10: 38 jobs --------
#
# ------Cluster 11: 65 jobs --------
#
# ------Cluster 12: 10 jobs --------
#
# ------Cluster 13: 54 jobs --------
#
# ------Cluster 14: 44 jobs --------
#
# ------Cluster 15: 20 jobs --------
#
# ------Cluster 16: 1 jobs --------
#
# ------Cluster 17: 14 jobs --------
#
# ------Cluster 18: 28 jobs --------
#
# ------Cluster 19: 36 jobs --------
#
# ------Cluster 20: 23 jobs --------
#
# ------Cluster 21: 32 jobs --------
#
# ------Cluster 22: 8 jobs --------
#
# ------Cluster 23: 5 jobs --------
#
# ------Cluster 24: 45 jobs --------
#
# ------Cluster 25: 42 jobs --------
#
# ------Cluster 26: 16 jobs --------
#
# ------Cluster 27: 65 jobs --------
#
# ------Cluster 28: 83 jobs --------
#
# ------Cluster 29: 15 jobs --------
#
# ------Cluster 30: 45 jobs --------
#
# ------Cluster 31: 12 jobs --------
#
# ------Cluster 32: 37 jobs --------
#
# ------Cluster 33: 43 jobs --------
#
# ------Cluster 34: 54 jobs --------
#
# ------Cluster 35: 18 jobs --------
#
# ------Cluster 36: 9 jobs --------
#
# ------Cluster 37: 59 jobs --------
#
# ------Cluster 38: 10 jobs --------
#
# ------Cluster 39: 5 jobs --------
#
# ------Cluster 40: 11 jobs --------
#
# ------Cluster 41: 4 jobs --------
#
# ------Cluster 42: 6 jobs --------
#
# ------Cluster 43: 29 jobs --------
#
# ------Cluster 44: 37 jobs --------
#
# ------Cluster 45: 26 jobs --------
#
# ------Cluster 46: 12 jobs --------
#
# ------Cluster 47: 8 jobs --------
#
# ------Cluster 48: 8 jobs --------
#
# ------Cluster 49: 4 jobs --------
#
# ------Cluster 50: 67 jobs --------
#
# ------Cluster 51: 9 jobs --------
#
# ------Cluster 52: 34 jobs --------
#
# ------Cluster 53: 12 jobs --------
#
# ------Cluster 54: 23 jobs --------

# %%
# plot the results
clusters = [c for c in range(best_k)]
colors = cm.rainbow(np.linspace(0, 1, Ks[3]))
for cluster, c in zip(clusters, colors):
    data = np.array(dict_of_clusters[cluster])
    plt.scatter(data[:, 0], data[:, 1], color=c)

# %% [markdown]
# # PART 2 - Order The Clusters

# %%
# centers (centroids) of clusters
centers = best_kmeans.cluster_centers_

# %%
# radius of the Earth
R = 6373.0

def compute_distance(place_1, place_2):
    """
    compute the distance between two lat-long coordinates

    Input:

    place_1 - tuple : (latitude, longitude) of place 1
    place_2 - tuple : (latitude, longitude) of place 2

    Returns:
    distance - float number 
    """    
    
    distance_lat = place_2[0] - place_1[0]
    distance_long = place_2[1] - place_1[1]

    #Haverinse formula 
    x = math.sin(distance_lat / 2)**2 + math.cos(place_1[0]) * math.cos(place_2[0]) * math.sin(distance_long / 2)**2

    y = 2 * math.atan2(math.sqrt(x), math.sqrt(1 - x))

    return R * y

# %% [markdown]
# ### 2a -
# - Order the cluster according to the distances between them.
# - All data points in the same cluster will get the same index.

# %%
# order the clusters according to distance from cluster 0 

d_array = [(0,0)]
c_0 = centers[0]
for idx, c in enumerate(centers[1:]):
    d_array += [(compute_distance(c_0, c), idx + 1)]
cluster_distance = sorted(d_array, key=lambda x: x[0]) 

dict_cluster_to_idx = {c[1] : idx for idx, c in enumerate(cluster_distance)}

idx_res_column = []

# for each row add the relevent number according to the order of the clusters
for label in labels:
    idx_res_column += [dict_cluster_to_idx[label]]

# %%
# add the column to the dataFrame
df['IDC_Index__c'] = idx_res_column

# %%
# craete result new excel
df.to_excel(f'results_{name_of_file}_(2a).xlsx', sheet_name='results')

# %% [markdown]
# ### 2b -
# Order the cluters by executing shortest path algorithm on each cluster.

# %%
# seprate the datapoints according to their cluster
# save id = job's row.
separate_dataset = [[] for cluster in range(best_k)]
id = 0
for datapoint, label in zip(dataset, labels):
    separate_dataset[label].append((id, datapoint))
    id += 1

# %% [markdown]
# Shoretest path Algorithm:
# ### Dijkstra algorithm
#
# - We execute SP on every cluster according to the order we achieved above.
# - Fisrt iteration:
#     - Startpoint: take random datapoint
#     - Endpoint: random datapoint from the next cluster
# - Next iterations:
#     - StartPoint: the endpoint from the previous iteration
#     - Endpoint: random datapoint from the next cluster

# %%
# save the oredr of the clusters
cluster_order = [c[1] for c in cluster_distance]

# %%
MAX_VALUE = sys.float_info.max

# %%
class Vertex: 
    
    def __init__(self, job, is_root=False):
        self.id = job[0]
        self.place = job[1]
        self.distance = 0 if (is_root) else MAX_VALUE
        self.parent = None


    def relax(self, v):
        distance_from_self_to_v = compute_distance(self.place, v.place) 
        if v.distance > self.distance + distance_from_self_to_v:
            v.distance = self.distance + distance_from_self_to_v
            v.parent = self.id
            
    # implemt =, < for using heapq on vertex
    def __eq__(self, other):
        if self.distance == other.distance:
            return True
        else:
            return False

    def __lt__(self, other):
        if self.distance < other.distance:
            return True
        else:
            return False

# %%
idx = 0
results = []
for cluster in range(best_k):
    root = Vertex(separate_dataset[cluster][0], is_root=True)
    G = [Vertex(datapoint) for datapoint in separate_dataset[cluster][1:]]
    G.append(root)
    # we do not use E since there are edges between all the vertices
    #E = [(v1.id, v2.id) for v1 in G for v2 in G]

    # ------- Execute DIJKSTRA -------- #
    priority_queue = []
    #push all vertices
    for v in G:
        heapq.heappush(priority_queue, v)
    while priority_queue != []:
        # dequeue the smallest vertex (according to the distance field)
        u = heapq.heappop(priority_queue)
        results.append((u.id, idx)) #u.index = idx  ->. at Dijkstra the first to leave th queue is the closet to the begining
        for v in G:
            u.relax(v)
        idx +=1

# %%
#sort result according to rows order ('id')
results.sort(key=lambda row: row[0])
results = [row[1] for row in results]

# %%
# add the column to the dataFrame
df['IDC_Index__c'] = results

# %%
# craete result new excel
df.to_excel(f'results_{name_of_file}_(2b).xlsx', sheet_name='results')

# %% [markdown]
# ### 2c -
# - For each cluster perform Kmeans inside him and create sub-cluster
# - Order the cluster according to the distances between them.
# - All data points in the same sub-cluster will get the same index.

# %%
df = pd.read_excel(f'results_{name_of_file}_(2a).xlsx')

# %%
# K to check for the KMeans
Ks = [k for k in range(2, 10)]

# %%
dict_of_clusters_2c = {}
index_2c = 0

for cluster in clusters:
    #todo
    dataset = dict_of_clusters[cluster]
    inertia_lst = []
    print(f'cluster : {cluster} length:  {len(dataset)}')
    if(len(dataset) > 10):
        for k in Ks:
            kmeans = KMeans(n_clusters=k, random_state=0)
            # fit the data
            _ = kmeans.fit_predict(dataset)
            # save inertia
            inertia_lst.append(kmeans.inertia_)
        # plot inertia as function of number of clusers (k)
    
        #print(plt.plot(Ks, inertia_lst, marker=11))
    
        # finding the elbow
        length = len(inertia_lst) - 1

        # delta_1: index=0 -> #cluster=2 -> best_k_idx=1
        delta_1 = [inertia_lst[i] - inertia_lst[i+1] for i in range(length)]

        # delta_2: index 0 -> #cluster=3 -> best_k_idx=2
        delta_2 = [delta_1[i] - delta_1[i+1] for i in range(length - 1)]

        strength = [(i, delta_2[i+1] - delta_1[i+2]) for i in range(length - 2) if delta_1[i+1] >= 0 and delta_2[i+1] >= 0]

        best_k_idx = max(strength,key=lambda t: t[1])[0] + 2
        best_k = Ks[best_k_idx]
    
        # get the best KMeans , n_clusters=best_k
        best_kmeans = KMeans(n_clusters=best_k, random_state=0)
    
        # seperate the instances to clusters

        # get labels 
        labels = best_kmeans.fit_predict(dataset)

        # init dictionary
        dict_of_clusters_2 = {cluster: [] for cluster in range(best_k)}

        for idx, instance in enumerate(dataset):
            dict_of_clusters_2[labels[idx]].append(instance)
        
        # print cluster sizes
        for cluster, instances in dict_of_clusters_2.items():
            #print(f'------Cluster {cluster}: {len(instances)} jobs --------')
            #print()
            dict_of_clusters_2c.update({index_2c: instances}) 
            index_2c += 1
        
        # centers (centroids) of clusters
        centers = best_kmeans.cluster_centers_
    
    else:
        dict_of_clusters_2c.update({index_2c: dataset}) 
        index_2c += 1
            
    
#print(centers)
# Out:
# cluster : 0 length:  21
# cluster : 1 length:  5
# cluster : 2 length:  6
# cluster : 3 length:  123
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 4 length:  18
# cluster : 5 length:  30
# cluster : 6 length:  48
# cluster : 7 length:  42
# cluster : 8 length:  17
# cluster : 9 length:  64
# cluster : 10 length:  38
# cluster : 11 length:  65
# cluster : 12 length:  10
# cluster : 13 length:  54
# cluster : 14 length:  44
# cluster : 15 length:  20
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 16 length:  1
# cluster : 17 length:  14
# cluster : 18 length:  28
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 19 length:  36
# cluster : 20 length:  23
# cluster : 21 length:  32
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 22 length:  8
# cluster : 23 length:  5
# cluster : 24 length:  45
# cluster : 25 length:  42
# cluster : 26 length:  16
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 27 length:  65
# cluster : 28 length:  83
# cluster : 29 length:  15
# cluster : 30 length:  45
# cluster : 31 length:  12
# cluster : 32 length:  37
# cluster : 33 length:  43
# cluster : 34 length:  54
# cluster : 35 length:  18
# cluster : 36 length:  9
# cluster : 37 length:  59
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 38 length:  10
# cluster : 39 length:  5
# cluster : 40 length:  11
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 41 length:  4
# cluster : 42 length:  6
# cluster : 43 length:  29
# cluster : 44 length:  37
# cluster : 45 length:  26
# cluster : 46 length:  12
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# cluster : 47 length:  8
# cluster : 48 length:  8
# cluster : 49 length:  4
# cluster : 50 length:  67
# cluster : 51 length:  9
# cluster : 52 length:  34
# cluster : 53 length:  12
# cluster : 54 length:  23
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# C:\Users\yonat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1122: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_

# %%
for cluster, instances in dict_of_clusters_2c.items():
    for instance in instances:
        inds = np.where(np.logical_and(df['Latitude'].values  == instance[0],df['Longitude'].values == instance[1]))[0]
        #print(np.logical_and(df['Latitude'].values  == instance[0],df['Longitude'].values == instance[1]))
        #print(inds)
        #print(instance, cluster)
        #print(df[['Latitude','Longitude']].iloc[inds])
        df['IDC_Index__c'].iloc[inds] = cluster
        #print(df['IDC_Index__c'].iloc[inds])
# Out:
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [269 285 290 299 311 315 328]
# [ 19.42613  -99.135282] 0
#      Latitude  Longitude
# 269  19.42613 -99.135282
# 285  19.42613 -99.135282
# 290  19.42613 -99.135282
# 299  19.42613 -99.135282
# 311  19.42613 -99.135282
# 315  19.42613 -99.135282
# 328  19.42613 -99.135282
# 269    0
# 285    0
# 290    0
# 299    0
# 311    0
# 315    0
# 328    0
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [239 246]
# [ 19.44115 -99.14177] 1
#      Latitude  Longitude
# 239  19.44115  -99.14177
# 246  19.44115  -99.14177
# 239    1
# 246    1
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [241 287]
# [ 19.439139 -99.143435] 1
#       Latitude  Longitude
# 241  19.439139 -99.143435
# 287  19.439139 -99.143435
# 241    1
# 287    1
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [239 246]
# [ 19.44115 -99.14177] 1
#      Latitude  Longitude
# 239  19.44115  -99.14177
# 246  19.44115  -99.14177
# 239    1
# 246    1
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [241 287]
# [ 19.439139 -99.143435] 1
#       Latitude  Longitude
# 241  19.439139 -99.143435
# 287  19.439139 -99.143435
# 241    1
# 287    1
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [876]
# [ 19.436265 -99.138955] 1
#       Latitude  Longitude
# 876  19.436265 -99.138955
# 876    1
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 236  266  770  772  794 1588]
# [ 19.439013 -99.133858] 2
#        Latitude  Longitude
# 236   19.439013 -99.133858
# 266   19.439013 -99.133858
# 770   19.439013 -99.133858
# 772   19.439013 -99.133858
# 794   19.439013 -99.133858
# 1588  19.439013 -99.133858
# 236     2
# 266     2
# 770     2
# 772     2
# 794     2
# 1588    2
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 236  266  770  772  794 1588]
# [ 19.439013 -99.133858] 2
#        Latitude  Longitude
# 236   19.439013 -99.133858
# 266   19.439013 -99.133858
# 770   19.439013 -99.133858
# 772   19.439013 -99.133858
# 794   19.439013 -99.133858
# 1588  19.439013 -99.133858
# 236     2
# 266     2
# 770     2
# 772     2
# 794     2
# 1588    2
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 236  266  770  772  794 1588]
# [ 19.439013 -99.133858] 2
#        Latitude  Longitude
# 236   19.439013 -99.133858
# 266   19.439013 -99.133858
# 770   19.439013 -99.133858
# 772   19.439013 -99.133858
# 794   19.439013 -99.133858
# 1588  19.439013 -99.133858
# 236     2
# 266     2
# 770     2
# 772     2
# 794     2
# 1588    2
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 236  266  770  772  794 1588]
# [ 19.439013 -99.133858] 2
#        Latitude  Longitude
# 236   19.439013 -99.133858
# 266   19.439013 -99.133858
# 770   19.439013 -99.133858
# 772   19.439013 -99.133858
# 794   19.439013 -99.133858
# 1588  19.439013 -99.133858
# 236     2
# 266     2
# 770     2
# 772     2
# 794     2
# 1588    2
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 236  266  770  772  794 1588]
# [ 19.439013 -99.133858] 2
#        Latitude  Longitude
# 236   19.439013 -99.133858
# 266   19.439013 -99.133858
# 770   19.439013 -99.133858
# 772   19.439013 -99.133858
# 794   19.439013 -99.133858
# 1588  19.439013 -99.133858
# 236     2
# 266     2
# 770     2
# 772     2
# 794     2
# 1588    2
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 236  266  770  772  794 1588]
# [ 19.439013 -99.133858] 2
#        Latitude  Longitude
# 236   19.439013 -99.133858
# 266   19.439013 -99.133858
# 770   19.439013 -99.133858
# 772   19.439013 -99.133858
# 794   19.439013 -99.133858
# 1588  19.439013 -99.133858
# 236     2
# 266     2
# 770     2
# 772     2
# 794     2
# 1588    2
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [33]
# [ 19.444195 -99.13271 ] 3
#      Latitude  Longitude
# 33  19.444195  -99.13271
# 33    3
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [45]
# [ 19.443852 -99.132788] 3
#      Latitude  Longitude
# 45  19.443852 -99.132788
# 45    3
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [816]
# [ 19.443818 -99.130792] 3
#       Latitude  Longitude
# 816  19.443818 -99.130792
# 816    3
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 15 904 912]
# [  28.41215  -106.855635] 4
#      Latitude   Longitude
# 15   28.41215 -106.855635
# 904  28.41215 -106.855635
# 912  28.41215 -106.855635
# 15     4
# 904    4
# 912    4
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [261 867]
# [  28.41091  -106.855185] 4
#      Latitude   Longitude
# 261  28.41091 -106.855185
# 867  28.41091 -106.855185
# 261    4
# 867    4
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [261 867]
# [  28.41091  -106.855185] 4
#      Latitude   Longitude
# 261  28.41091 -106.855185
# 867  28.41091 -106.855185
# 261    4
# 867    4
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 15 904 912]
# [  28.41215  -106.855635] 4
#      Latitude   Longitude
# 15   28.41215 -106.855635
# 904  28.41215 -106.855635
# 912  28.41215 -106.855635
# 15     4
# 904    4
# 912    4
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 15 904 912]
# [  28.41215  -106.855635] 4
#      Latitude   Longitude
# 15   28.41215 -106.855635
# 904  28.41215 -106.855635
# 912  28.41215 -106.855635
# 15     4
# 904    4
# 912    4
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 77 304 331 339 351 356]
# [  22.44785 -102.35063] 5
#      Latitude  Longitude
# 77   22.44785 -102.35063
# 304  22.44785 -102.35063
# 331  22.44785 -102.35063
# 339  22.44785 -102.35063
# 351  22.44785 -102.35063
# 356  22.44785 -102.35063
# 77     5
# 304    5
# 331    5
# 339    5
# 351    5
# 356    5
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 77 304 331 339 351 356]
# [  22.44785 -102.35063] 5
#      Latitude  Longitude
# 77   22.44785 -102.35063
# 304  22.44785 -102.35063
# 331  22.44785 -102.35063
# 339  22.44785 -102.35063
# 351  22.44785 -102.35063
# 356  22.44785 -102.35063
# 77     5
# 304    5
# 331    5
# 339    5
# 351    5
# 356    5
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 77 304 331 339 351 356]
# [  22.44785 -102.35063] 5
#      Latitude  Longitude
# 77   22.44785 -102.35063
# 304  22.44785 -102.35063
# 331  22.44785 -102.35063
# 339  22.44785 -102.35063
# 351  22.44785 -102.35063
# 356  22.44785 -102.35063
# 77     5
# 304    5
# 331    5
# 339    5
# 351    5
# 356    5
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 77 304 331 339 351 356]
# [  22.44785 -102.35063] 5
#      Latitude  Longitude
# 77   22.44785 -102.35063
# 304  22.44785 -102.35063
# 331  22.44785 -102.35063
# 339  22.44785 -102.35063
# 351  22.44785 -102.35063
# 356  22.44785 -102.35063
# 77     5
# 304    5
# 331    5
# 339    5
# 351    5
# 356    5
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 77 304 331 339 351 356]
# [  22.44785 -102.35063] 5
#      Latitude  Longitude
# 77   22.44785 -102.35063
# 304  22.44785 -102.35063
# 331  22.44785 -102.35063
# 339  22.44785 -102.35063
# 351  22.44785 -102.35063
# 356  22.44785 -102.35063
# 77     5
# 304    5
# 331    5
# 339    5
# 351    5
# 356    5
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 77 304 331 339 351 356]
# [  22.44785 -102.35063] 5
#      Latitude  Longitude
# 77   22.44785 -102.35063
# 304  22.44785 -102.35063
# 331  22.44785 -102.35063
# 339  22.44785 -102.35063
# 351  22.44785 -102.35063
# 356  22.44785 -102.35063
# 77     5
# 304    5
# 331    5
# 339    5
# 351    5
# 356    5
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [393]
# [ 19.511395 -99.097942] 6
#       Latitude  Longitude
# 393  19.511395 -99.097942
# 393    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [606]
# [ 19.512085 -99.098261] 6
#       Latitude  Longitude
# 606  19.512085 -99.098261
# 606    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [647]
# [ 19.511358 -99.09807 ] 6
#       Latitude  Longitude
# 647  19.511358  -99.09807
# 647    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [696]
# [ 19.512157 -99.09828 ] 6
#       Latitude  Longitude
# 696  19.512157  -99.09828
# 696    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [698]
# [ 19.512303 -99.098319] 6
#       Latitude  Longitude
# 698  19.512303 -99.098319
# 698    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [707]
# [ 19.511559 -99.097215] 6
#       Latitude  Longitude
# 707  19.511559 -99.097215
# 707    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [785]
# [ 19.511462 -99.097607] 6
#       Latitude  Longitude
# 785  19.511462 -99.097607
# 785    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [987]
# [ 19.511904 -99.096873] 6
#       Latitude  Longitude
# 987  19.511904 -99.096873
# 987    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [989]
# [ 19.512057 -99.097546] 6
#       Latitude  Longitude
# 989  19.512057 -99.097546
# 989    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [999]
# [ 19.51213  -99.097353] 6
#      Latitude  Longitude
# 999  19.51213 -99.097353
# 999    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [1035]
# [ 19.509647 -99.096493] 6
#        Latitude  Longitude
# 1035  19.509647 -99.096493
# 1035    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [1097]
# [ 19.512169 -99.097482] 6
#        Latitude  Longitude
# 1097  19.512169 -99.097482
# 1097    6
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [430]
# [ 19.510759 -99.102754] 7
#       Latitude  Longitude
# 430  19.510759 -99.102754
# 430    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [588]
# [ 19.510913 -99.101374] 7
#       Latitude  Longitude
# 588  19.510913 -99.101374
# 588    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [590]
# [ 19.51029 -99.10164] 7
#      Latitude  Longitude
# 590  19.51029  -99.10164
# 590    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [652]
# [ 19.510831 -99.101492] 7
#       Latitude  Longitude
# 652  19.510831 -99.101492
# 652    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [699]
# [ 19.510465 -99.100236] 7
#       Latitude  Longitude
# 699  19.510465 -99.100236
# 699    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [752]
# [ 19.51141  -99.100614] 7
#      Latitude  Longitude
# 752  19.51141 -99.100614
# 752    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [755]
# [ 19.511508 -99.101355] 7
#       Latitude  Longitude
# 755  19.511508 -99.101355
# 755    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [768]
# [ 19.51002 -99.10158] 7
#      Latitude  Longitude
# 768  19.51002  -99.10158
# 768    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [877]
# [ 19.509834 -99.101267] 7
#       Latitude  Longitude
# 877  19.509834 -99.101267
# 877    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [936]
# [ 19.511264 -99.099705] 7
#       Latitude  Longitude
# 936  19.511264 -99.099705
# 936    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [939]
# [ 19.5112   -99.099936] 7
#      Latitude  Longitude
# 939   19.5112 -99.099936
# 939    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [1036]
# [ 19.511295 -99.100275] 7
#        Latitude  Longitude
# 1036  19.511295 -99.100275
# 1036    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [1100]
# [ 19.511196 -99.100556] 7
#        Latitude  Longitude
# 1100  19.511196 -99.100556
# 1100    7
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [492]
# [ 19.505308 -99.097471] 8
#       Latitude  Longitude
# 492  19.505308 -99.097471
# 492    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [571]
# [ 19.506818 -99.1     ] 8
#       Latitude  Longitude
# 571  19.506818      -99.1
# 571    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [623]
# [ 19.507262 -99.099859] 8
#       Latitude  Longitude
# 623  19.507262 -99.099859
# 623    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [658]
# [ 19.507409 -99.096763] 8
#       Latitude  Longitude
# 658  19.507409 -99.096763
# 658    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [672]
# [ 19.507442 -99.098379] 8
#       Latitude  Longitude
# 672  19.507442 -99.098379
# 672    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [688]
# [ 19.506756 -99.099219] 8
#       Latitude  Longitude
# 688  19.506756 -99.099219
# 688    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [736]
# [ 19.507243 -99.098186] 8
#       Latitude  Longitude
# 736  19.507243 -99.098186
# 736    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [759]
# [ 19.507212 -99.098362] 8
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#       Latitude  Longitude
# 759  19.507212 -99.098362
# 759    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [932]
# [ 19.506932 -99.099925] 8
#       Latitude  Longitude
# 932  19.506932 -99.099925
# 932    8
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [
# 1090    9
# 1092    9
# 1099    9
# 1101    9
# Name: IDC_Index__c, dtype: int64
# [False False False ... False False False]
# [ 333  371  577  578  580  581  583  585  602  607  629  631  646  656
#   693  694  708  740  742  744  756  764  782  784  952  955  980  988
#  1008 1038 1046 1062 1064 1066 1074 1090 1092 1099 1101]
# [ 19.50868 -99.09898] 9
#       Latitude  Longitude
# 333   19.50868  -99.09898
# 371   19.50868  -99.09898
# 577   19.50868  -99.09898
# 578   19.50868  -99.09898
# 580   19.50868  -99.09898
# 581   19.50868  -99.09898
# 583   19.50868  -99.09898
# 585   19.50868  -99.09898
# 602   19.50868  -99.09898
# 607   19.50868  -99.09898
# 629   19.50868  -99.09898
# 631   19.50868  -99.09898
# 646   19.50868  -99.09898
# 656   19.50868  -99.09898
# 693   19.50868  -99.09898
# 694   19.50868  -99.09898
# 708   19.50868  -99.09898
# 740   19.50868  -99.09898
# 742   19.50868  -99.09898
# 744   19.50868  -99.09898
# 756   19.50868  -99.09898
# 764   19.50868  -99.09898
# 782   19.50868  -99.09898
# 784   19.50868  -99.09898
# 952   19.50868  -99.09898
# 955   19.50868  -99.09898
# 980   19.50868  -99.09898
# 988   19.50868  -99.09898
# 1008  19.50868  -99.09898
# 1038  19.50868  -99.09898
# 1046  19.50868  -99.09898
# 1062  19.50868  -99.09898
# 1064  19.50868  -99.09898
# 1066  19.50868  -99.09898
# 1074  19.50868  -99.09898
# 1090  19.50868  -99.09898
# 1092  19.50868  -99.09898
# 1099  19.50868  -99.09898
# 1101  19.50868  -99.09898
# 333     9
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yonat\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
# craete result new excel
df.to_excel(f'results_{name_of_file}_(2c).xlsx', sheet_name='results')

# %%
df
# Out:
#       Unnamed: 0                     _                  Id AppointmentNumber  \
# 0              0  [ServiceAppointment]  08p4L000000lKERQA2           SA-4051
# 1              1  [ServiceAppointment]  08p4L000000lKESQA2           SA-4052
# 2              2  [ServiceAppointment]  08p4L000000lKETQA2           SA-4053
# 3              3  [ServiceAppointment]  08p4L000000lKEUQA2           SA-4054
# 4              4  [ServiceAppointment]  08p4L000000lKEVQA2           SA-4055
# ...          ...                   ...                 ...               ...
# 1495        1495  [ServiceAppointment]  08p4L000000lKBOQA2           SA-3862
# 1496        1496  [ServiceAppointment]  08p4L000000lKBXQA2           SA-3871
# 1497        1497  [ServiceAppointment]  08p4L000000lKBYQA2           SA-3872
# 1498        1498  [ServiceAppointment]  08p4L000000lKBZQA2           SA-3873
# 1499        1499  [ServiceAppointment]  08p4L000000lKBaQAM           SA-3874
#
#        Latitude  Longitude  IDC_Index__c
# 0     19.476372 -99.179075            97
# 1     19.476439 -99.179061            97
# 2     19.476439 -99.179061            97
# 3     19.476439 -99.179061            97
# 4     19.476461 -99.179056            97
# ...         ...        ...           ...
# 1495  19.477986 -99.179773            26
# 1496  19.477986 -99.179773            26
# 1497  19.477986 -99.179773            26
# 1498  19.477986 -99.179773            26
# 1499  19.477986 -99.179773            26
#
# [1500 rows x 7 columns]
